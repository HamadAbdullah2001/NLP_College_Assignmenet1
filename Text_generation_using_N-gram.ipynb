# %% [markdown]
# # Import Software Libraries

# %%
import nltk
from nltk.corpus import PlaintextCorpusReader
from nltk.tokenize import word_tokenize
from nltk.util import ngrams
from collections import Counter
import random
# Out:
# C:\Users\Hamad\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Load the Quarn Dataset

# %%
corpus = open('./Corpus/A/A/aa1.txt', encoding='utf-8').read()

# %% [markdown]
# # Tokenize the Words

# %%
tokens = word_tokenize(corpus)

# %% [markdown]
# # Generate N-gram models

# %%
n = 6
n_grams = []
for i in range(2, n+1):
    n_grams.extend(ngrams(tokens, i))

# %% [markdown]
# # Count the frequency of words

# %%
# Count the frequency of each N-gram
ngrams_freq = Counter(n_grams)

# %% [markdown]
# # Write the most 10 frequent words on a text file (without removing stop words)

# %%
# Get the 20 most frequent tokens
top_10_freq_with_sw = ngrams_freq.most_common(10)

with open('top_10_freq_with_sw.txt', 'w', encoding='utf-8') as f:
    for word, freq in top_10_freq_with_sw:
        f.write(' '.join(word) + '\t' + str(freq) + '\n')
        
f = open('top_10_freq_with_sw.txt', encoding='utf-8').read()
print(f)
# Out:
# إن الله	205
# الذين آمنوا	184
# في الأرض	176
# يا أيها	142
# الذين كفروا	134
# السماوات والأرض	133
# الرحمن الرحيم	118
# الله الرحمن	114
# بسم الله	114
# الله الرحمن الرحيم	114

# %% [markdown]
# # The method of removing the stop words

# %%
stop_words = set(nltk.corpus.stopwords.words('arabic'))

new_tokens = []

for token in tokens:
    if token not in stop_words:
        new_tokens.append(token)

# %% [markdown]
# # Reprocess the same process with removing stop words

# %%
n_grams = []
for i in range(1, n):
    n_grams.extend(ngrams(new_tokens, i))

ngrams_freq_wo_sw = Counter(n_grams)

top_10_freq_without_sw = ngrams_freq_wo_sw.most_common(10)

with open('top_10_freq_without_sw.txt', 'w', encoding='utf-8') as f:
    for word, freq in top_10_freq_without_sw:
        f.write(' '.join(word) + '\t' + str(freq) + '\n')

# %% [markdown]
# # The most 10 frequent words with removing the stop words

# %%
f = open('top_10_freq_without_sw.txt', encoding='utf-8').read()
print(f)
# Out:
# الله	2265
# قال	416
# قل	294
# الأرض	287
# آمنوا	263
# قالوا	250
# والله	240
# كانوا	229
# ربك	220
# يوم	217

# %%
# Generate text using N-gram models
num_tokens = int(input('Enter the number of tokens: '))
start_word = input('Enter the start word: ')
# Out:
# Enter the number of tokens: 10
# Enter the start word: الحمد

# %%
prediction = [start_word]

while len(prediction) < num_tokens:
    
    c = prediction[-(n-1):]
    
    if tuple(c) in ngrams_freq:
        
        while True:
            try :
                next_token = random.choices(
                    list(ngrams_freq_wo_sw[tuple(c)].keys()),
                    weights=ngrams_freq_wo_sw[tuple(c)].values()
                )[0]
                break
            except :
                pass
        
        prediction.append(next_token)
        
    else:
        next_token = random.choice(tokens)
        prediction.append(next_token)

s = ' '.join(prediction)
print(s)
# Out:
# الحمد موسى والله بيني المنافقون قال يكسبون وزنوا سم الرياح

# %% [markdown]
# # Now, let's use the same methods with different inputs to evaluate and test the outputs.

# %%
lst_s_words = [
    'الحمد',
    'محمد',
    'الله',
    'موسى',
    'الم',
    'الجنة',
    'المسلمون',
    'عيسى'
]

table = {
    'Sample_Test' : [],
    'Num_of_Words' : [],
    'Start_Word' : [],
    'Predicted_Text' : []
}

n = 6
sample_test = 1

for num in range(6, 10+1):
    for s_word in lst_s_words:
        
        num_tokens = num
        start_word = s_word
        prediction = [start_word]

        while len(prediction) < num_tokens:
            
            c = prediction[-(n-1):]
            
            if tuple(c) in ngrams_freq:
                while True:
                    try :
                        new_token = random.choices(
                            list(ngrams_freq_wo_sw[tuple(c)].keys()),
                            weights=ngrams_freq_wo_sw[tuple(c)].values()
                        )[0]
                        break
                    except :
                        new_token = random.choice(tokens)
                        break
                    
                prediction.append(new_token)
                
            else:
                next_token = random.choice(tokens)
                prediction.append(next_token)

        table['Sample_Test'].append(sample_test)
        sample_test += 1
        table['Num_of_Words'].append(num)
        table['Start_Word'].append(start_word)
        text = ' '.join(w for w in prediction)
        table['Predicted_Text'].append(text)
        
        print(f'Sample {num_tokens} and {start_word} done.')
# Out:
# Sample 6 and الحمد done.
# Sample 6 and محمد done.
# Sample 6 and الله done.
# Sample 6 and موسى done.
# Sample 6 and الم done.
# Sample 6 and الجنة done.
# Sample 6 and المسلمون done.
# Sample 6 and عيسى done.
# Sample 7 and الحمد done.
# Sample 7 and محمد done.
# Sample 7 and الله done.
# Sample 7 and موسى done.
# Sample 7 and الم done.
# Sample 7 and الجنة done.
# Sample 7 and المسلمون done.
# Sample 7 and عيسى done.
# Sample 8 and الحمد done.
# Sample 8 and محمد done.
# Sample 8 and الله done.
# Sample 8 and موسى done.
# Sample 8 and الم done.
# Sample 8 and الجنة done.
# Sample 8 and المسلمون done.
# Sample 8 and عيسى done.
# Sample 9 and الحمد done.
# Sample 9 and محمد done.
# Sample 9 and الله done.
# Sample 9 and موسى done.
# Sample 9 and الم done.
# Sample 9 and الجنة done.
# Sample 9 and المسلمون done.
# Sample 9 and عيسى done.
# Sample 10 and الحمد done.
# Sample 10 and محمد done.
# Sample 10 and الله done.
# Sample 10 and موسى done.
# Sample 10 and الم done.
# Sample 10 and الجنة done.
# Sample 10 and المسلمون done.
# Sample 10 and عيسى done.

# %%
import pandas as pd

table = pd.DataFrame(table)
table
# Out:
#     Sample_Test  Num_of_Words Start_Word  \
# 0             1             6      الحمد
# 1             2             6       محمد
# 2             3             6       الله
# 3             4             6       موسى
# 4             5             6        الم
# 5             6             6      الجنة
# 6             7             6   المسلمون
# 7             8             6       عيسى
# 8             9             7      الحمد
# 9            10             7       محمد
# 10           11             7       الله
# 11           12             7       موسى
# 12           13             7        الم
# 13           14             7      الجنة
# 14           15             7   المسلمون
# 15           16             7       عيسى
# 16           17             8      الحمد
# 17           18             8       محمد
# 18           19             8       الله
# 19           20             8       موسى
# 20           21             8        الم
# 21           22             8      الجنة
# 22           23             8   المسلمون
# 23           24             8       عيسى
# 24           25             9      الحمد
# 25           26             9       محمد
# 26           27             9       الله
# 27           28             9       موسى
# 28           29             9        الم
# 29           30             9      الجنة
# 30           31             9   المسلمون
# 31           32             9       عيسى
# 32           33            10      الحمد
# 33           34            10       محمد
# 34           35            10       الله
# 35           36            10       موسى
# 36           37            10        الم
# 37           38            10      الجنة
# 38           39            10   المسلمون
# 39           40            10       عيسى
#
#                                        Predicted_Text
# 0                    الحمد ومنكم كبيرا ومن خالدين قوم
# 1                  محمد شهود يعصينك صلاتهم يطعمني ربي
# 2                 الله جاءتهم تستعجلون ذلك وكن لنذهبن
# 3                        موسى وأرسلنا فمن آيتين ما به
# 4                        الم بشرى وعلمك وإذا وقيل ربه
# 5                        الجنة يشاء لعلكم بما به عاما
# 6                       المسلمون لي لهم بيوتكن كتب ما
# 7                    عيسى كذبوا بسم وقومه استكبروا من
# 8                     الحمد أكل ومن لنا من لسان رأوها
# 9             محمد اليمين واذكروا فإن ويوم إنهم الرعب
# 10                       الله بأس لهم لكم في أتاك ملك
# 11            موسى الذين الذي يعمهون خبيرا كتاب ذريتي
# 12            الم سنجزي أخواتكم رحمته الله وأما الصدع
# 13                الجنة من فرعون واد النعيم جهنم وجعل
# 14             المسلمون لعلكم من يوم يصحبون في وأولئك
# 15                عيسى الله من وإن وأنا والمؤمنون نفس
# 16          الحمد أرسلناك وقوم ولا إن لتبلغوا إليه لا
# 17                 محمد ما عينا يا ورسوله في رضوان من
# 18           الله كفروا تتخذوا إنه في وقنا يأتيكم لهم
# 19               موسى أمرنا من سرق رقبة عوجا عندنا لا
# 20          الم مال إنما ضيفي وإني والأرض الأحزاب وأن
# 21  الجنة الكاذبين كانوا على رحمته آباؤكم ونبلوكم ...
# 22            المسلمون يسجد قد إلا إلى فأما لهم مسفرة
# 23          عيسى ولكن نخلفه وهو أسلموا فإذا الله كنتم
# 24         الحمد الناس كنتم الذين لنا ومن من له عربيا
# 25  محمد وبنين كتابا ذاقوا كذبا يعودون يقول هداكم ...
# 26  الله عقلوه فاتبعوني ومقاما عذاب عن قليلا حبا ف...
# 27      موسى الرزاق يا فتصبح مزقتم لمن ائتوا عدو شرعا
# 28       الم فما وإذا صدرا يرونه وإليه الله يخربون ثم
# 29   الجنة تفجيرا نفسا شديد جئتكم فأولئك أليم وترى من
# 30  المسلمون بعد ويقدر لهم قضينا ولما ويحرمونه ألم...
# 31    عيسى كان أنفسهن خاسرين أنا نفسي نساؤكم أإذا إلى
# 32  الحمد ضيق كاتبون الشيطان المجرمين للناس إن الح...
# 33  محمد ربي فيها وظنوا أن يسألونك فضل يعدهم وإن بعده
# 34  الله لأزيدنكم فيه لنحيي مشفقون الله يقول من يو...
# 35   موسى إليه من وأطيعون الشمس بسم وأتوني مع الحق ما
# 36  الم لم علي أفأمنوا ما بعد قولهم والأرض ويميت ضعفا
# 37  الجنة وإن تأويله أن وفي القتال الحساب فضلتكم و...
# 38  المسلمون أسوأ له الله ليأخذ منهم عنكم ولا شهيد...
# 39   عيسى الذين إلا بل كيف في يعطوا أتخذناهم غني منهم

# %% [markdown]
# # Unnecessary code, just for saving the table.

# %%
table.to_csv('sample_examples_table.csv')
